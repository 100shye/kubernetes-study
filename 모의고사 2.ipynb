# %% [markdown]
# #### 문제 1
# ![image.png](attachment:image.png)
# #### 정답
# 1. etcd pod describe를 보자 data 저장경로 찾게. 그러고 cheat sheet의 etcdctl 명령어 따라쓰면됨
# ![image-6.png](attachment:image-6.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# ![image-5.png](attachment:image-5.png)

# %% [markdown]
# #### 문제 2
# ![image.png](attachment:image.png)
#
# #### 정답
# pod랑 emtydir cheat sheet에 검색하면 됨
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# #### 문제 3
# ![image.png](attachment:image.png)
# #### 정답
# SYS_TIME을 cheat sheet에 검색해봄. command yaml도 검색해서 명령어 추가해줌
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# #### 문제 4
# ![image.png](attachment:image.png)
# #### 정답
#  - pv이름 pv-1, pvc이름 my-pvc로 pod 연결하기
# 1. pvc랑 pv를 만든다.(cheat sheet에 persistent volume 쳐보기)
# 2. pod에 pv, pvc 입력하고 파일 실행
# pv 만들어진거 보면 access mode 가 pvc에도 동일한 값으로 적혀있어야힘
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# #### 문제 5
# ![image.png](attachment:image.png)
# #### 정답
# 1. deploy 만들고 ( deploy roll out이라고 검색해봄)
# 2. 업데이트 함
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# #### 문제 6
# ![image-2.png](attachment:image-2.png)
# #### 정답
# ![image.png](attachment:image.png)
# #### role 이름은 developer
# #### 기능은 create, list, get, update and delete,
# #### namespace는 developemt
#  kubectl create role developer --verb=get --verb=list --verb=create --verb=update --verb=delete
#  --resource=pods -n development
#
#   - role 생성됨
#   ![image-3.png](attachment:image-3.png)

# %% [markdown]
# #### 문제 7
#  - pod name: nginx-resolver
#  - image: nginx
#  - service name: nginx-resolver-service
#  - dns lookup: busybox: 1.28
# ![image.png](attachment:image.png)
# 1. pod 생성
# 2. expose로 서비스 연결
# 3. busybox에 sleep 4000 명령어 추가해서 만들기
# 4. busybox로 pod랑 service lookup
#
#  - pod의 dns이름 형식에 맞춰서 nslookup 해야함
# ![image-2.png](attachment:image-2.png)
#  - service는 그냥 이름써서 nslookup 하면됨(아이피주소 .말고 - 로 연결해서 써야함)

# %% [markdown]
# #### 문제 8
# ![image.png](attachment:image.png)
#  - static pod node를 치트시트에 검색
#  - ssh로 해당 노도 ip 추가해주고 static pod 만들어주면 됨
