# %% [markdown]
# 3:16 pm 시작~

# %% [markdown]
# #### 문제 1
# ![image.png](attachment:image.png)
#
# #### 정답
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# #### 문제 2
# ![image.png](attachment:image.png)
#
# #### 정답
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# #### 문제 3
# ![image.png](attachment:image.png)
# #### 정답
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# #### 문제 4
# ![image.png](attachment:image.png)
# #### 정답
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# #### 문제 5
# 1. 서비스 만들고 2. 앱에 연결하기
# ![image.png](attachment:image.png)
#
# #### 정답
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# #### 문제 6
# ![image-2.png](attachment:image-2.png)
# #### 정답
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 문제 7
# ![image.png](attachment:image.png)
#
# #### 정답 모르겠으니까 cheat sheet에 쳐보자
# 1. kublet 검색해서 staticp pod 실행되는 path 알아내기
#  -  kubelet config 파일에 staticpath 가 있어서
# 2. static path로 넘어가서 node랑 pod 연결하는법 cheat sheet에 검색해서 yaml 만들기
# 3. command도 cheat sheet에 검색해서 만들기
# 4. 파일 실행

# %% [markdown]
# #### 문제 8
# ![image.png](attachment:image.png)
#
# #### 정답
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# #### 문제 9
# ![image.png](attachment:image.png)
# #### 정답
# 파드 편집해서 스펠링 고침
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# #### 문제 10
# ![image.png](attachment:image.png)
# #### 정답
# service 생성하고, nodeport는 30082, port는 8080d로 edit 다시 해줌
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# #### 문제 11
# ![image-2.png](attachment:image-2.png)
#
# #### 정답
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# #### 문제 12
# ![image.png](attachment:image.png)
#
# #### 정답
#  - cheat sheet에 persistant volume 검색해서 yaml만들면 됨
# ![image-2.png](attachment:image-2.png)
