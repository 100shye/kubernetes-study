# %% [markdown]
# #### 문제1
# ![image.png](attachment:image.png)
#  - cluster role 만들고(명령어로 만듦)
#  - serviceaccount 만들고(명령어로 만듦)
#  - cluster role binding 만듦(명령어로 만듦)
#  - describe cluster role binding 해서 확인한번하기
#  - pod 만들기 service는 명령어로 못만들어서 yaml로 만들고 serviceaccountname 줄 추가해줘야함

# %% [markdown]
# #### 문제 2
#  - json에서 값 너무 많으니까 grep으로 internalip만 확인가능. -B 100 붙이면 100줄 before까지 확인가능
# 2. | jq -c 'paths' 쓰면 internalip 경로 확인가능
# ![image.png](attachment:image.png)
# 3. https://kubernetes.io/docs/reference/kubectl/quick-reference/ 에서 jpath의 특정 값만 확인하는 구문으로 internelip가져오기
